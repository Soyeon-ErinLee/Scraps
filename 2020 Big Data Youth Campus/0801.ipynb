# %% [markdown]
# ## Pipeline 사용 목적

# %%
from sklearn.pipeline import Pipeline, make_pipeline

# %%
import seaborn as sns

# %%
iris = sns.load_dataset('iris')

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(iris.iloc[:,:-1],iris.species)

# %%
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor

# %%
pipe = Pipeline([('ss', StandardScaler()), ('knn', KNeighborsClassifier())])

# %%
vars(pipe)
# Out:
# {'steps': [('ss', StandardScaler()), ('knn', KNeighborsClassifier())],
#  'memory': None,
#  'verbose': False}

# %%
from sklearn.model_selection import GridSearchCV

# %%
knn = KNeighborsClassifier()

# %%
knn.get_params()
# Out:
# {'algorithm': 'auto',
#  'leaf_size': 30,
#  'metric': 'minkowski',
#  'metric_params': None,
#  'n_jobs': None,
#  'n_neighbors': 5,
#  'p': 2,
#  'weights': 'uniform'}

# %%
grid = GridSearchCV(knn, {'n_neighbors':range(2,10)})

# %%
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': range(2, 10)})

# %%
import pandas as pd

# %%
pd.DataFrame(grid.cv_results_).T
# Out:
#                                     0                   1                   2  \
# mean_fit_time              0.00299149          0.00239177          0.00219231
# std_fit_time               0.00154465          0.00048995         0.000400423
# mean_score_time            0.00259337          0.00239577          0.00239325
# std_score_time            0.000488112         0.000486871         0.000488422
# param_n_neighbors                   2                   3                   4
# params             {'n_neighbors': 2}  {'n_neighbors': 3}  {'n_neighbors': 4}
# split0_test_score            0.869565            0.956522            0.956522
# split1_test_score            0.956522            0.956522            0.956522
# split2_test_score            0.818182            0.863636            0.818182
# split3_test_score            0.954545            0.954545            0.954545
# split4_test_score            0.954545            0.954545            0.954545
# mean_test_score              0.910672            0.937154            0.928063
# std_test_score              0.0569143           0.0367695           0.0549478
# rank_test_score                     8                   6                   7
#
#                                     3                   4                   5  \
# mean_fit_time              0.00139623                   0                   0
# std_fit_time              0.000797784                   0                   0
# mean_score_time            0.00180845          0.00312471          0.00312462
# std_score_time            0.000980177          0.00624943          0.00624924
# param_n_neighbors                   5                   6                   7
# params             {'n_neighbors': 5}  {'n_neighbors': 6}  {'n_neighbors': 7}
# split0_test_score                   1                   1                   1
# split1_test_score            0.956522            0.956522            0.956522
# split2_test_score            0.863636            0.818182            0.954545
# split3_test_score            0.954545                   1                   1
# split4_test_score            0.954545            0.954545            0.954545
# mean_test_score               0.94585             0.94585            0.973123
# std_test_score              0.0446238           0.0668627           0.0219572
# rank_test_score                     4                   4                   1
#
#                                     6                   7
# mean_fit_time               0.0062479          0.00312424
# std_fit_time               0.00765209          0.00624847
# mean_score_time                     0                   0
# std_score_time                      0                   0
# param_n_neighbors                   8                   9
# params             {'n_neighbors': 8}  {'n_neighbors': 9}
# split0_test_score            0.956522            0.956522
# split1_test_score            0.956522            0.956522
# split2_test_score            0.863636            0.863636
# split3_test_score                   1                   1
# split4_test_score            0.954545            0.954545
# mean_test_score              0.946245            0.946245
# std_test_score              0.0447077           0.0447077
# rank_test_score                     2                   2

# %%
grid = GridSearchCV(knn, {'n_neighbors':range(2,10), 'p': [2,3,4]})

# %%
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': range(2, 10), 'p': [2, 3, 4]})

# %%
pd.DataFrame(grid.cv_results_).T
# Out:
#                                            0                           1   \
# mean_fit_time                      0.00271273                  0.00219364
# std_fit_time                       0.00075284                 0.000976854
# mean_score_time                    0.00337582                  0.00239391
# std_score_time                    0.000500437                 0.000488364
# param_n_neighbors                           2                           2
# param_p                                     2                           3
# params             {'n_neighbors': 2, 'p': 2}  {'n_neighbors': 2, 'p': 3}
# split0_test_score                    0.869565                    0.869565
# split1_test_score                    0.956522                    0.956522
# split2_test_score                    0.818182                    0.818182
# split3_test_score                    0.954545                           1
# split4_test_score                    0.954545                    0.954545
# mean_test_score                      0.910672                    0.919763
# std_test_score                      0.0569143                   0.0660871
# rank_test_score                            24                          21
#
#                                            2                           3   \
# mean_fit_time                      0.00219498                  0.00159569
# std_fit_time                      0.000398352                 0.000488675
# mean_score_time                    0.00259209                  0.00219421
# std_score_time                    0.000487841                 0.000399089
# param_n_neighbors                           2                           3
# param_p                                     4                           2
# params             {'n_neighbors': 2, 'p': 4}  {'n_neighbors': 3, 'p': 2}
# split0_test_score                    0.869565                    0.956522
# split1_test_score                    0.956522                    0.956522
# split2_test_score                    0.818182                    0.863636
# split3_test_score                           1                    0.954545
# split4_test_score                    0.954545                    0.954545
# mean_test_score                      0.919763                    0.937154
# std_test_score                      0.0660871                   0.0367695
# rank_test_score                            21                          16
#
#                                            4                           5   \
# mean_fit_time                      0.00352478                  0.00312347
# std_fit_time                       0.00610104                  0.00624695
# mean_score_time                   0.000211811                           0
# std_score_time                    0.000423622                           0
# param_n_neighbors                           3                           3
# param_p                                     3                           4
# params             {'n_neighbors': 3, 'p': 3}  {'n_neighbors': 3, 'p': 4}
# split0_test_score                    0.956522                    0.956522
# split1_test_score                    0.913043                    0.913043
# split2_test_score                    0.863636                    0.863636
# split3_test_score                    0.954545                    0.954545
# split4_test_score                    0.954545                    0.954545
# mean_test_score                      0.928458                    0.928458
# std_test_score                      0.0362991                   0.0362991
# rank_test_score                            17                          17
#
#                                            6                           7   \
# mean_fit_time                      0.00312428                  0.00312419
# std_fit_time                       0.00624857                  0.00624838
# mean_score_time                             0                  0.00312428
# std_score_time                              0                  0.00624857
# param_n_neighbors                           4                           4
# param_p                                     2                           3
# params             {'n_neighbors': 4, 'p': 2}  {'n_neighbors': 4, 'p': 3}
# split0_test_score                    0.956522                    0.913043
# split1_test_score                    0.956522                    0.956522
# split2_test_score                    0.818182                    0.818182
# split3_test_score                    0.954545                    0.954545
# split4_test_score                    0.954545                    0.954545
# mean_test_score                      0.928063                    0.919368
# std_test_score                      0.0549478                   0.0531676
# rank_test_score                            20                          23
#
#                                            8                           9   \
# mean_fit_time                               0                  0.00312409
# std_fit_time                                0                  0.00624819
# mean_score_time                    0.00312448                           0
# std_score_time                     0.00624895                           0
# param_n_neighbors                           4                           5
# param_p                                     4                           2
# params             {'n_neighbors': 4, 'p': 4}  {'n_neighbors': 5, 'p': 2}
# split0_test_score                    0.913043                           1
# split1_test_score                    0.956522                    0.956522
# split2_test_score                    0.818182                    0.863636
# split3_test_score                           1                    0.954545
# split4_test_score                    0.954545                    0.954545
# mean_test_score                      0.928458                     0.94585
# std_test_score                      0.0616195                   0.0446238
# rank_test_score                            17                          12
#
#                    ...                          14  \
# mean_fit_time      ...                           0
# std_fit_time       ...                           0
# mean_score_time    ...                  0.00313234
# std_score_time     ...                  0.00626469
# param_n_neighbors  ...                           6
# param_p            ...                           4
# params             ...  {'n_neighbors': 6, 'p': 4}
# split0_test_score  ...                    0.956522
# split1_test_score  ...                    0.956522
# split2_test_score  ...                    0.863636
# split3_test_score  ...                           1
# split4_test_score  ...                    0.954545
# mean_test_score    ...                    0.946245
# std_test_score     ...                   0.0447077
# rank_test_score    ...                           7
#
#                                            15                          16  \
# mean_fit_time                               0                  0.00312452
# std_fit_time                                0                  0.00624905
# mean_score_time                    0.00312395                           0
# std_score_time                      0.0062479                           0
# param_n_neighbors                           7                           7
# param_p                                     2                           3
# params             {'n_neighbors': 7, 'p': 2}  {'n_neighbors': 7, 'p': 3}
# split0_test_score                           1                    0.956522
# split1_test_score                    0.956522                    0.956522
# split2_test_score                    0.954545                    0.954545
# split3_test_score                           1                           1
# split4_test_score                    0.954545                    0.954545
# mean_test_score                      0.973123                    0.964427
# std_test_score                      0.0219572                   0.0178085
# rank_test_score                             1                           2
#
#                                            17                          18  \
# mean_fit_time                      0.00624847                  0.00312424
# std_fit_time                       0.00765279                  0.00624847
# mean_score_time                             0                           0
# std_score_time                              0                           0
# param_n_neighbors                           7                           8
# param_p                                     4                           2
# params             {'n_neighbors': 7, 'p': 4}  {'n_neighbors': 8, 'p': 2}
# split0_test_score                    0.956522                    0.956522
# split1_test_score                    0.956522                    0.956522
# split2_test_score                    0.909091                    0.863636
# split3_test_score                           1                           1
# split4_test_score                    0.954545                    0.954545
# mean_test_score                      0.955336                    0.946245
# std_test_score                      0.0287643                   0.0447077
# rank_test_score                             3                           7
#
#                                            19                          20  \
# mean_fit_time                               0                           0
# std_fit_time                                0                           0
# mean_score_time                             0                  0.00624843
# std_score_time                              0                  0.00765273
# param_n_neighbors                           8                           8
# param_p                                     3                           4
# params             {'n_neighbors': 8, 'p': 3}  {'n_neighbors': 8, 'p': 4}
# split0_test_score                    0.956522                    0.913043
# split1_test_score                    0.956522                    0.956522
# split2_test_score                    0.863636                    0.863636
# split3_test_score                           1                           1
# split4_test_score                    0.954545                    0.954545
# mean_test_score                      0.946245                    0.937549
# std_test_score                      0.0447077                   0.0460708
# rank_test_score                             7                          15
#
#                                            21                          22  \
# mean_fit_time                      0.00312657                  0.00312257
# std_fit_time                       0.00625315                  0.00624514
# mean_score_time                             0                           0
# std_score_time                              0                           0
# param_n_neighbors                           9                           9
# param_p                                     2                           3
# params             {'n_neighbors': 9, 'p': 2}  {'n_neighbors': 9, 'p': 3}
# split0_test_score                    0.956522                    0.956522
# split1_test_score                    0.956522                    0.956522
# split2_test_score                    0.863636                    0.909091
# split3_test_score                           1                           1
# split4_test_score                    0.954545                    0.954545
# mean_test_score                      0.946245                    0.955336
# std_test_score                      0.0447077                   0.0287643
# rank_test_score                             7                           3
#
#                                            23
# mean_fit_time                               0
# std_fit_time                                0
# mean_score_time                     0.0031846
# std_score_time                     0.00636921
# param_n_neighbors                           9
# param_p                                     4
# params             {'n_neighbors': 9, 'p': 4}
# split0_test_score                    0.913043
# split1_test_score                    0.956522
# split2_test_score                    0.909091
# split3_test_score                           1
# split4_test_score                    0.954545
# mean_test_score                       0.94664
# std_test_score                      0.0333049
# rank_test_score                             6
#
# [15 rows x 24 columns]

# %%
grid = GridSearchCV(knn, {'n_neibhbors':range(2,10), 'leaf size': [20,30]})

# %%
pipe3 = Pipeline([('ss', StandardScaler()),('clf', KNeighborsClassifier())])

# %%
from sklearn.linear_model import LogisticRegression

# %%
grid2 = GridSearchCV(pipe3, [
    {'clf':[KNeighborsClassifier()], 'clf__n_neighbors':[2,3,4,5]},
    {'clf':[LogisticRegression()], 'clf__C':[1,2,3,4,5]}
])

# %%
grid2.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('ss', StandardScaler()),
#                                        ('clf', KNeighborsClassifier())]),
#              param_grid=[{'clf': [KNeighborsClassifier()],
#                           'clf__n_neighbors': [2, 3, 4, 5]},
#                          {'clf': [LogisticRegression(C=2)],
#                           'clf__C': [1, 2, 3, 4, 5]}])

# %%
from sklearn.compose import ColumnTransformer

# %%
mpg = sns.load_dataset('mpg')

# %%
mpg.drop(columns='name', inplace = True)

# %%
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin
# 0            70     usa
# 1            70     usa
# 2            70     usa
# 3            70     usa
# 4            70     usa
# ..          ...     ...
# 393          82     usa
# 394          82  europe
# 395          82     usa
# 396          82     usa
# 397          82     usa
#
# [398 rows x 8 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(mpg.iloc[:,1:],mpg['mpg'])

# %%
from sklearn.impute import SimpleImputer

# %%
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder

# %%
pipe1 = Pipeline([('imputer', SimpleImputer())])
pipe2 = Pipeline([('la', LabelEncoder())])
pipe3 = Pipeline([('ss', StandardScaler())])

# %%
ct = ColumnTransformer([
    ('im', pipe1, 'horsepower'),
    ('l', pipe2, 'origin'),
    ('s', pipe3, ['cylinders','displacement'])
])

# %%
od = OrdinalEncoder()

# %%
od.fit_transform(mpg[['origin']])
# Out:
# array([[2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [1.],
#        [2.],
#        [2.],
#        [2.],
#        [1.],
#        [0.],
#        [0.],
#        [0.],
#        [0.],
#        [0.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [1.],
#        [2.],
#        [1.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [0.],
#        [0.],
#        [0.],
#        [1.],
#        [1.],
#        [0.],
#        [2.],
#        [1.],
#        [2.],
#        [0.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [1.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [0.],
#        [0.],
#        [0.],
#        [0.],
#        [2.],
#        [1.],
#        [1.],
#        [2.],
#        [1.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [0.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [1.],
#        [2.],
#        [1.],
#        [1.],
#        [2.],
#        [2.],
#        [0.],
#        [2.],
#        [2.],
#        [0.],
#        [0.],
#        [0.],
#        [0.],
#        [2.],
#        [0.],
#        [1.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [1.],
#        [2.],
#        [1.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [0.],
#        [0.],
#        [0.],
#        [1.],
#        [1.],
#        [2.],
#        [0.],
#        [0.],
#        [1.],
#        [1.],
#        [0.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [1.],
#        [2.],
#        [2.],
#        [2.],
#        [1.],
#        [0.],
#        [1.],
#        [2.],
#        [0.],
#        [2.],
#        [0.],
#        [0.],
#        [0.],
#        [0.],
#        [1.],
#        [0.],
#        [0.],
#        [2.],
#        [2.],
#        [0.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [0.],
#        [1.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [0.],
#        [1.],
#        [1.],
#        [2.],
#        [0.],
#        [2.],
#        [0.],
#        [1.],
#        [0.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [1.],
#        [2.],
#        [0.],
#        [2.],
#        [1.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [0.],
#        [2.],
#        [1.],
#        [2.],
#        [2.],
#        [2.],
#        [1.],
#        [0.],
#        [1.],
#        [0.],
#        [1.],
#        [0.],
#        [2.],
#        [1.],
#        [1.],
#        [1.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [1.],
#        [1.],
#        [2.],
#        [1.],
#        [2.],
#        [2.],
#        [1.],
#        [0.],
#        [0.],
#        [0.],
#        [0.],
#        [0.],
#        [1.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [0.],
#        [1.],
#        [2.],
#        [2.],
#        [0.],
#        [2.],
#        [0.],
#        [2.],
#        [2.],
#        [2.],
#        [1.],
#        [0.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [0.],
#        [1.],
#        [2.],
#        [1.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [0.],
#        [1.],
#        [1.],
#        [1.],
#        [1.],
#        [1.],
#        [2.],
#        [1.],
#        [0.],
#        [0.],
#        [0.],
#        [0.],
#        [1.],
#        [0.],
#        [1.],
#        [0.],
#        [1.],
#        [1.],
#        [0.],
#        [2.],
#        [1.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [1.],
#        [2.],
#        [1.],
#        [1.],
#        [1.],
#        [1.],
#        [1.],
#        [2.],
#        [2.],
#        [2.],
#        [0.],
#        [0.],
#        [1.],
#        [1.],
#        [1.],
#        [1.],
#        [0.],
#        [0.],
#        [1.],
#        [1.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [0.],
#        [1.],
#        [1.],
#        [2.],
#        [2.],
#        [1.],
#        [1.],
#        [1.],
#        [1.],
#        [1.],
#        [1.],
#        [2.],
#        [2.],
#        [2.],
#        [2.],
#        [1.],
#        [2.],
#        [2.],
#        [2.],
#        [0.],
#        [2.],
#        [2.],
#        [2.]])

# %%
le = LabelEncoder()

# %%
import numpy as np

# %%
xx = np.arange(12).reshape(3,4)

# %%
le.fit_transform(mpg[['origin']])
# Out:
# C:\Users\Erin Lee\Anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# array([2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 1, 0, 0, 0,
#        0, 0, 2, 2, 2, 2, 2, 1, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 0, 0, 0, 1, 1, 0, 2, 1, 2, 0, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 0, 0, 0, 0, 2, 1, 1, 2, 1, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 2, 1, 2,
#        1, 1, 2, 2, 0, 2, 2, 0, 0, 0, 0, 2, 0, 1, 2, 2, 2, 2, 2, 1, 2, 1,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 0, 0, 1, 1, 2, 0, 0, 1, 1, 0, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 1, 0, 1, 2, 0,
#        2, 0, 0, 0, 0, 1, 0, 0, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0,
#        1, 2, 2, 2, 2, 0, 1, 1, 2, 0, 2, 0, 1, 0, 2, 2, 2, 2, 1, 2, 0, 2,
#        1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 2, 1, 2, 2, 2, 1, 0, 1,
#        0, 1, 0, 2, 1, 1, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 1, 1, 2, 1, 2, 2, 1, 0, 0, 0, 0, 0, 1, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 0, 1, 2, 2, 0, 2, 0, 2, 2, 2, 1, 0, 2, 2, 2,
#        2, 0, 1, 2, 1, 2, 2, 2, 2, 0, 1, 1, 1, 1, 1, 2, 1, 0, 0, 0, 0, 1,
#        0, 1, 0, 1, 1, 0, 2, 1, 2, 2, 2, 2, 2, 1, 2, 1, 1, 1, 1, 1, 2, 2,
#        2, 0, 0, 1, 1, 1, 1, 0, 0, 1, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 0, 1, 1, 2, 2, 1, 1, 1, 1, 1, 1, 2, 2, 2, 2, 1, 2, 2, 2, 0, 2,
#        2, 2])

# %%
le.fit(mpg.origin)
# Out:
# LabelEncoder()

# %%
import inspect

# %%
print(inspect.getsource(LabelEncoder.fit_transform))
# Out:
#     def fit_transform(self, y):
#         """Fit label encoder and return encoded labels
#
#         Parameters
#         ----------
#         y : array-like of shape [n_samples]
#             Target values.
#
#         Returns
#         -------
#         y : array-like of shape [n_samples]
#         """
#         y = column_or_1d(y, warn=True)
#         self.classes_, y = _encode(y, encode=True)
#         return y

# %%
class ModifiedLabelEncoder(LabelEncoder):
    def fit_transform(self, y, *arg, **kwarg):
        from sklearn.utils import column_or_1d
        y = column_or_1d(y)
        return super().fit_transform(y).reshape(-1,1)
    def transform(self, y, *arg, **kwarg):
        from sklearn.utils import column_or_1d
        y = column_or_1d(y)
        return super().transform(y).reshape(-1,1)

# %%
pipe1 = Pipeline([('imputer', SimpleImputer(strategy = 'median'))])
pipe2 = Pipeline([('la', ModifiedLabelEncoder())])
pipe3 = Pipeline([('ss', StandardScaler())])

# %%
ct = ColumnTransformer([
    ('im', pipe1, ['horsepower']),
    ('l', pipe2, ['origin']),
    ('s', pipe3, ['cylinders','displacement'])
])

# %%
ct.fit_transform(X_train, y_train)
# Out:
# array([[193.        ,   2.        ,   1.54080172,   1.08335997],
#        [170.        ,   2.        ,   1.54080172,   2.01227429],
#        [ 88.        ,   2.        ,  -0.84134569,  -0.77446868],
#        ...,
#        [ 70.        ,   2.        ,  -0.84134569,  -0.84220201],
#        [102.        ,   0.        ,  -0.84134569,  -0.60029724],
#        [ 90.        ,   0.        ,  -0.84134569,  -0.90993535]])

# %%
pipe = Pipeline([('ct',ct), ('knn', KNeighborsRegressor())])

# %%
pipe
# Out:
# Pipeline(steps=[('ct',
#                  ColumnTransformer(transformers=[('im',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median'))]),
#                                                   ['horsepower']),
#                                                  ('l',
#                                                   Pipeline(steps=[('la',
#                                                                    ModifiedLabelEncoder())]),
#                                                   ['origin']),
#                                                  ('s',
#                                                   Pipeline(steps=[('ss',
#                                                                    StandardScaler())]),
#                                                   ['cylinders',
#                                                    'displacement'])])),
#                 ('knn', KNeighborsRegressor())])

# %%
X_train, X_test, y_train, y_test = train_test_split(mpg.iloc[:,1:],mpg['mpg'])

# %%
grid3 = GridSearchCV(pipe, {'ct__im__imputer__strategy':['median','mean']})

# %%
grid3.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('ct',
#                                         ColumnTransformer(transformers=[('im',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(strategy='median'))]),
#                                                                          ['horsepower']),
#                                                                         ('l',
#                                                                          Pipeline(steps=[('la',
#                                                                                           ModifiedLabelEncoder())]),
#                                                                          ['origin']),
#                                                                         ('s',
#                                                                          Pipeline(steps=[('ss',
#                                                                                           StandardScaler())]),
#                                                                          ['cylinders',
#                                                                           'displacement'])])),
#                                        ('knn', KNeighborsRegressor())]),
#              param_grid={'ct__im__imputer__strategy': ['median', 'mean']})

# %%
from sklearn.ensemble import VotingClassifier

# %%
from sklearn.naive_bayes import GaussianNB

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
vc = VotingClassifier([('GB', GaussianNB()), ('RF', RandomForestClassifier()), ('KNN', KNeighborsClassifier())])

# %%
import seaborn as sns

# %%
iris = sns.load_dataset('iris')

# %%
vc.fit(iris.iloc[:,:-1], iris.species)
# Out:
# VotingClassifier(estimators=[('GB', GaussianNB()),
#                              ('RF', RandomForestClassifier()),
#                              ('KNN', KNeighborsClassifier())])

# %%
from sklearn.ensemble import BaggingClassifier

# %%
bc = BaggingClassifier()

# %%
bc.fit(iris.iloc[:,:-1], iris.species)
# Out:
# BaggingClassifier()

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
ada = AdaBoostClassifier()

# %%
ada.fit(iris.iloc[:,:-1], iris.species)
# Out:
# AdaBoostClassifier()

# %%
from sklearn.ensemble import StackingClassifier

# %%
sc = StackingClassifier([('GB', GaussianNB()), ('RF',RandomForestClassifier(), ('Knn', KNeighborsClassifier()))])

# %%
sc.fit(iris.iloc[:,:-1],iris.species)
# Out:
# StackingClassifier(estimators=[('GB', GaussianNB()),
#                                ('RF', RandomForestClassifier(),
#                                 ('Knn', KNeighborsClassifier()))])
